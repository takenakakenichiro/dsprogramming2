# %%
import sqlite3
# !pwd
# Out:
# /Users/kenichiro/Desktop/dsprogramming2/dsprogramming2

# %%
#データベースに接続する

# %%
path = "/Users/kenichiro/Desktop/dsprogramming2/dsprogramming2/"
db_name = "TVnews.sqlite"
con = sqlite3.connect(path + db_name)
con.close()

# %%
con = sqlite3.connect(path + db_name)
cur = con.cursor()
create_name = "CREATE TABLE TVnews (date text, topic text);"
# テーブルの作成
cur.execute(create_name)
# コミットとクローズ
con.commit()
con.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/kenichiro/Desktop/dsprogramming2/dsprogramming2/final.ipynb セル 3 line 5
#       <a href='vscode-notebook-cell:/Users/kenichiro/Desktop/dsprogramming2/dsprogramming2/final.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> create_name = "CREATE TABLE TVnews (date text, topic text);"
#       <a href='vscode-notebook-cell:/Users/kenichiro/Desktop/dsprogramming2/dsprogramming2/final.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> # テーブルの作成
# ----> <a href='vscode-notebook-cell:/Users/kenichiro/Desktop/dsprogramming2/dsprogramming2/final.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> cur.execute(create_name)
#       <a href='vscode-notebook-cell:/Users/kenichiro/Desktop/dsprogramming2/dsprogramming2/final.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> # コミットとクローズ
#       <a href='vscode-notebook-cell:/Users/kenichiro/Desktop/dsprogramming2/dsprogramming2/final.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> con.commit()
#
# OperationalError: table TVnews already exists

# %%
#connect to
con = sqlite3.connect(path + db_name)

#get object
cur = con.cursor()

#insert into 
insert_many = 'INSERT INTO TVnews VALUES (?, ?);'

#prepare a list
TVnews_list = [("12月26日", "山本投手移籍"),
("12月27日", "イスラエル軍ガザ中部にも拡大"),
("12月28日", "阿部派強制捜査"),
("12月29日", "ロシア軍事侵攻16人死亡"),
("12月30日", "歌手、八代亜紀さん死亡"),
("12月31日", "ロシア軍攻撃による死者46人に"),
("1月1日", "地震"),
("1月2日", "地震"),
("1月3日", "地震"),
("1月4日", "地震"),
("1月5日", "地震"),
("1月6日", "航空機炎上"),
("1月7日", "自民党安倍派池田議員逮捕"),
("1月8日", "地震"),
("1月9日", "地震")]

#execute
cur.executemany(insert_many, TVnews_list)

#commit prosessing
con.commit()

#db close
con.close()

# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in /Users/kenichiro/Library/Python/3.9/lib/python/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/kenichiro/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4) (2.5)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#Netnews list
Netnews_list= []

#scraping
import requests
import csv
r=requests.get("https://www.asahi.com/news/")

encoding=r.encoding
if encoding.lower() == 'iso-8859-1':
    r.encoding = 'utf-8'

from bs4 import BeautifulSoup
soup=BeautifulSoup(r.text, 'html.parser')

tag=soup.find('ul', class_="List")

if tag is not None:
    for row in tag.find_all('li'):
        columns=row.find('a')
        if columns:
            target_data=columns.text
            print(target_data)
            Netnews_list.append(target_data)
else:
    print("none")
# Out:
# /Users/kenichiro/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 長野3連覇、箱根で涙の駒沢大・鈴木芽吹「恩返しを」　全国男子駅伝19:17
#
#
# 0
#
# 0
#
# 「電撃ネットワーク」南部虎弾さん死去　過激なパフォーマンスで人気18:40
#
#
# 0
#
# 0
#
# 人手確保のリアリズム　工科高を卒業する外国ルーツ生徒に企業の視線18:00
#
#
# 0
#
# 0
#
# 避難所で乾杯「不謹慎と言わないで」　夜な夜な出店する居酒屋の正体18:00
#
#
# 0
#
# 0
#
# ロシア市民の本音は　ウクライナ侵攻「反対」候補の事務所にできた列18:00
#
#
# 0
#
# 0
#
# 【速報中】ロシアの石油輸出港で2度の爆発　ドローン攻撃か17:56
#
#
# 0
#
# 0
#
# シーズン移行の針が動き出した瞬間　30年経て重なるJリーグの歴史17:45
#
#
# 0
#
# 0
#
# 【速報中】農水相、能登半島をヘリで視察「隆起の問題は大きな課題」17:44
#
#
# 0
#
# 0
#
# 野菜入りの弁当に安心、受験準備には不安　先行避難の中学生たちは今17:31
#
#
# 0
#
# 0
#
# 藤井聡太王将、菅井竜也八段に2連勝「すぐ来週、状態整え臨みたい」17:30
#
#
# 0
#
# 0
#
# 習氏、今年はG20に出席か　ブラジル訪問の王毅氏が伝達と現地報道17:04
#
#
# 0
#
# 0
#
# 午後5時にドアを開ける小学生　外国ルーツの子が巣立つ小さな部屋17:00
#
#
# 0
#
# 0
#
# 奥能登の被災酒蔵、残った「もろみ」を救え　県内外から支援の手17:00
#
#
# 0
#
# 0
#
# 亡き被災者の名を刻む重み　「能登」と「阪神」で考えた17:00
#
#
# 0
#
# 0
#
# 【そもそも解説】マイナ保険証、持っていないとどうなるの？16:30
#
#
# 0
#
# 0
#
# 二階派の福岡・宮内衆院議員は4年で161万円　「東京に現金保管」16:30
#
#
# 0
#
# 0
#
# 言葉もわからず、パリの菓子店に飛び込んだ　シェフに磨かれた表現力16:00
#
#
# 0
#
# 0
#
# 「マイ畑」で過去と向き合う少年たち　記者が少年院で見た食事風景16:00
#
#
# 0
#
# 0
#
# 母に反発して選んだ高校　「お前の文章ひどすぎ」から14年後の奇跡16:00
#
#
# 0
#
# 0
#
# 7年コンビニでバイトした青葉被告　「夢はないのか」責められ立腹15:00
#
#
# 0
#
# 0
#
# 自民・茂木氏「派閥は存続前提でない」　野党「解散はめくらまし」14:45
#
#
# 0
#
# 0
#
# 自主性は一番理想でも…山梨学院が「指導者の言う通り練習する」ワケ14:00
#
#
# 0
#
# 0
#
# 車中泊した翌日に逝ったおかんへ　「守ってあげられんくてごめんな」14:00
#
#
# 0
#
# 0
#
# 祭り屋台で「笑顔に」　露天商が避難所で炊き出し　子供連れら列13:42
#
#
# 0
#
# 0
#
# ガザめぐるSNS投稿で刑務所へ　29歳女性合唱団員に何が起きたか13:00
#
#
# 0
#
# 0
#
# 「0.1%」 障害のある議員が結集　当事者の声を政治に届けたい13:00
#
#
# 0
#
# 0
#
# 規模が広がる大企業の社会貢献、お金だけでなく人も　共創で課題解決13:00
#
#
# 0
#
# 0
#
# 「子どもたちの居場所を」　能登を愛する移住者たち、避難所で支援13:00
#
#
# 0
#
# 0
#
# ますだおかだの増田さん、出身地守口市の大使に「M-1のMは」12:52
#
#
# 0
#
# 0
#
# 人間の「おいしい」はニワトリに通じない？　実験で見えた味覚の違い12:30
#
#
# 0
#
# 0
#
# 近所に愛された犬「さくら」　最期を知らせた手紙が結んだ2つの幸せ12:00
#
#
# 0
#
# 0
#
# 学校制服に昭和以来のモデルチェンジの波　メーカーも「時代」に対応12:00
#
#
# 0
#
# 0
#
# 昔、受験生だったあなたへ　「受験英語」をずっと使える「英語力」に12:00
#
#
# 0
#
# 0
#
# 語り継がれる「ルミナリエおじさん」 企業に直談判、集めた5億円超12:00
#
#
# 0
#
# 0
#
# 自民・田村氏「なぜ裏金にしたのか、その使い道が一番の問題」12:00
#
#
# 0
#
# 0
#
# プーチン氏、早期の訪朝を表明　北朝鮮が報道、「熱烈歓迎の準備」12:00
#
#
# 0
#
# 0
#
# はなちゃんのランドセル上京　兄のジャンパーと　形見出す両親の訴え11:30
#
#
# 0
#
# 0
#
# きっかけは5分の動画　イタリアのダウン症の弟と兄の物語、映画に11:30
#
#
# 0
#
# 0
#
# パワハラでパート女性が自殺　遺族がユーコープを提訴「対応怠った」11:04
#
#
# 0
#
# 0
#
# うまみ凝縮の干し大根　漬けもの会社が感謝する「農家の丁寧な仕事」11:00
#
#
# 0
#
# 0
#
# 生成AIが作る未来は　安保と医療の専門家が予想する「異なる世界」11:00
#
#
# 0
#
# 0
#
# 自転車通学すると良く眠れる？　お昼寝時間導入の高校で生徒が研究11:00
#
#
# 0
#
# 0
#
# 脱通販で「ベスコス」大賞に　オルビス、改革の裏にあった社員の反発11:00
#
#
# 0
#
# 0
#
# 安倍派解散「断腸の思い」　元首相の地元、山口の議員らが反省の弁10:42
#
#
# 0
#
# 0
#
# 【速報中】ネタニヤフ首相「2国家解決」を否定　米国と溝深まる10:42
#
#
# 0
#
# 0
#
# 米袋の生地でCOMEバッグ　「技術絶やさず」メーカーの意地と誇り10:00
#
#
# 0
#
# 0
#
# めざせ、花いけバトルの甲子園　僕らが見つけた新たな「居場所」10:00
#
#
# 0
#
# 0
#
# 残業がなければ…サラリーマン川柳と令和の現代川柳、ノリの違いは10:00
#
#
# 0
#
# 0
#
# 1日1組限定の森の中のレストラン　NYで磨いたおもてなしをそえて10:00
#
#
# 0
#
# 0
#
# 今村翔吾さんが育てる「秘境の文筆家」　宮崎・椎葉村が募集へ10:00
#
#
# 0
#
# 0
#
# 新NISAつみたて投資枠、14%が毎月上限の10万円に　楽天証券10:00
#
#
# 0
#
# 0
#
# 外国ルーツの子の教育、もっと理解してほしいが…　日本語担当の葛藤09:30
#
#
# 0
#
# 0
#
# 「言葉の壁」なんてなくせば良い　学校向け多言語ツール発案者の思い09:30
#
#
# 0
#
# 0
#
# 妻の乳がんを知った日　私たち夫婦を救ったものは…　NYTコラム09:00
#
#
# 0
#
# 0
#
# 変わるべきは誰？　ユニークな「魔法」が注目される駄菓子屋の原点09:00
#
#
# 0
#
# 0
#
# 元川崎フロンターレ名物社員が新会社、スポーツと地域つなぐ架け橋に09:00
#
#
# 0
#
# 0
#
# 「はじめから勝算なかった」国主導企業の破綻　有機ELに見た幻想09:00
#
#
# 0
#
# 0
#
# 遺骨研究めぐり、アイヌ民族と研究者が対話「権利への配慮欠けた」09:00
#
#
# 0
#
# 0
#
# 「お金が循環するエコシステムを」起業家の非営利支援に時代の手応え08:30
#
#
# 0
#
# 0
#
# イランが「最も高い軌道」に衛星　大陸間ミサイルの開発短縮にも？08:08
#
#
# 0
#
# 0
#
# 「お前ならできる」恩師に支えられた青葉被告　幻覚も自然に消えた08:00
#
#
# 0
#
# 0
#
# 言語の次は画像モデル　CESで聞いた米専門家が描くAIの未来08:00
#
#
# 0
#
# 0
#
# 「よかれ」と思って無自覚カスハラ　気をつけたい「中高年男性」08:00
#
#
# 0
#
# 0
#
# がれき「1月1日のまま」　能登地震、災害ごみの搬出進まず08:00
#
#
# 0
#
# 0
#
# 「転機はドイツ戦の後半」　W杯優勝指揮官に刺激受けたホーバスHC08:00
#
#
# 0
#
# 0
#
# 元川崎フロンターレ名物社員が新会社、タッグ組むのは元BリーグGM07:45
#
#
# 0
#
# 0
#
# 「谷に落とされた」スキーヤーの父　娘が夢継いだ32年後の札幌五輪07:30
#
#
# 0
#
# 0
#
# 改善せぬ「人質司法」、裁判所も問題　明石順平さんのコメントプラス07:30
#
#
# 0
#
# 0
#
# 元社長「親会社からしたら赤字は…」　百貨店が不正に手を染めるまで07:30
#
#
# 0
#
# 0
#
# 「派閥が」「秘書が」　安倍派議員らの釈明相次ぐ　自身の責任は…？07:00
#
#
# 0
#
# 0
#
# 米政府予算成立せず3カ月　「つなぎ予算」頼みのタイムリミットは？07:00
#
#
# 0
#
# 0
#
# パトカーに「ホタル」の光　新たな赤色灯、音聞こえぬ人の不安解消へ06:00
#
#
# 0
#
# 0
#
# 「内苑の護持のため」、明治神宮側が語る外苑再開発　担当者に聞く06:00
#
#
# 0
#
# 0
#
# 京成百貨店元社長、雇調金詐欺の計画表作成を指示か　部下が証言05:30
#
#
# 0
#
# 0
#
# 焦点は派閥の弊害解消、自民党内は存廃綱引き　首相は本気度示せるか05:00
#
#
# 0
#
# 0
#
# 住宅内に血の付いた包丁　防犯カメラに女とは別の人物　足立夫婦遺棄05:00
#
#
# 0
#
# 0
#
# 堂本光一さん単独主演の舞台「SHOCK」、今年で24年の歴史に幕04:00
#
#
# 0
#
# 0
#
# バイデン氏とネタニヤフ氏が4週間ぶりに電話協議　2国家解決を議論1/20 22:35
#
#
# 0
#
# 0
#
# シリアでイラン軍事顧問5人死亡　イスラエル攻撃か、緊張高まる恐れ1/20 21:37
#
#
# 0
#
# 0
#
# 「夫を、息子を帰せ。譲歩しない」　動員兵の妻や母プーチン氏に抗議1/20 21:30
#
#
# 0
#
# 0
#
# 母の遺骨探して、「途方に暮れている」　倒壊した輪島の自宅で1/20 21:15
#
#
# 0
#
# 0
#
# 二階派の山梨県知事もノルマ超過分を不記載　1182万円分を修正1/20 21:10
#
#
# 0
#
# 0
#
# 「なかったら寂しいやんか」　2次避難進む集落　唯一の魚屋は再開へ1/20 21:00
#
#
# 0
#
# 0
#
# らしさ全開で金星、これぞ正代　「元大関って忘れたい」記者を笑わす1/20 20:57
#
#
# 0
#
# 0
#
# 住宅被害、石川県内で3万棟超える　輪島・珠洲市内はいまだ全容不明1/20 20:56
#
#
# 0
#
# 0
#
# 韓国総選挙へ向け活発化する「第三極」の動き　与野党の元代表が牽引1/20 20:30
#
#
# 0
#
# 0
#
# 電気・水道ないけれど　「自分は床屋」　倒壊免れた店で営業再開1/20 19:45
#
#
# 0
#
# 0
#
# 長峯誠参院議員、116万円の還流認める　不記載「気づかなかった」1/20 19:30
#
#
# 0
#
# 0
#
# 21日にかけ関東甲信で積雪予報、23区も　山沿いで警報級の可能性1/20 19:29
#
#
# 0
#
# 0
#
# 飲料水や食料、下着などトラック4台分を被災地へ搬送　東京都品川区1/20 19:00
#
#
# 0
#
# 0
#
# 政治資金パーティー甘いルール　公開基準、支払い、どう変えるべきか1/20 19:00
#
#
# 0
#
# 0
#
# 「ザル法」どころか大穴だらけ　政治資金規正法の甘くて緩い実態1/20 19:00
#
#
# 0
#
# 0
#
# 「寂しい気持ちはもちろん…」安倍派の解散、安倍昭恵氏が思い語る1/20 19:00
#
#
# 0
#
# 0
#
# 損保ジャパン社長に石川副社長が就任へ　辞任表明した白川氏の後任1/20 18:47
#
#
# 0
#
# 0
#
# 避難で車に同乗した男、車中泊中に10代女性にわいせつ容疑　輪島市1/20 18:41
#
#
# 0
#
# 0
#
# 着陸は一発勝負、難題挑んだSLIM　「月面開発先進国の仲間入り」1/20 18:30
#
#
# 0
#
# 0
#
# 相次ぐ近隣国攻撃、イランが内外に示したもの　識者が語る緊張の行方1/20 18:00
#
#
# 0
#
# 0
#
# ママの手術痕を見ないふりした　語られなかった母のがん、娘の悲しみ1/20 17:00
#
#
# 0
#
# 0
#
# 無数のひび割れに「ため息しか…」　輪島「白米千枚田」修復には時間1/20 17:00
#
#
# 0
#
# 0
#
# 「このままでは沈んでしまう」被災した和倉温泉、3団体が支援要望1/20 16:37
#
#
# 0
#
# 0
#
# 「下を向いてもいられん」能登島で寒ブリ漁再開、大物が次々と水揚げ1/20 16:30
#
#
# 0
#
# 0
#
# 内田樹さんが感じる　ちょっとおかしな語学教育　会話重視に異議あり1/20 16:00
#
#
# 0
#
# 0
#
# AIが数学オリンピックの難問証明　ひらめき獲得　数学者「ついに」1/20 16:00
#
#
# 0
#
# 0
#
# 能登半島の被災地、地区の半数が高齢化率5割以上　珠洲市は7割超1/20 16:00
#
#
# 0
#
# 0
#
# 後藤田正晴氏をソファに寝転がせた写真家　昨秋急逝し、徳島で追悼展1/20 16:00
#
#
# 0
#
# 0
#
# 足立区の保育園の健康診断で盗撮未遂、医師を現行犯逮捕1/20 15:44
#
#
# 0
#
# 0
#
# 「派閥幹部が責任を取らない」　368万円不記載の安倍派議員が謝罪1/20 15:19
#
#
# 0
#
# 0
#
# 奈良美智さん「売れていい気になっていた自分が…」　向き合った原点1/20 15:15
#
#
# 0
#
# 0
#
# パレスチナで高まるハマス人気　残虐動画は、8割が「見たことない」1/20 15:00
#
#
# 0
#
# 0
#
# ハマスは「罪なき人に災いもたらした」　ガザで上がり始めた批判の声1/20 15:00
#
#
# 0
#
# 0
#
# 薬のない避難所で弱るおばあちゃん　母が日記に残した29年前の震災1/20 15:00
#
#
# 0
#
# 0
#
# 水素エネルギーに200億円　小池百合子知事、2期目最後の目玉施策1/20 15:00
#
#
# 0
#
# 0
#
# 札幌国際芸術祭が開幕　「雪」テーマに気候変動や未来を考える1/20 15:00
#
#
# 0
#
# 0
#
# 「生態系を壊さない」見守りと介入　監督不在で知った楽しさ　甲府西1/20 14:00
#
#
# 0
#
# 0
#
# 仕事一筋だった父が残したアルバム「こんなに愛情を」　投稿すると…1/20 14:00
#
#
# 0
#
# 0
#
# 「神宿る島」見つめ、神を拝まず　小道に消えた女性、島民が救った1/20 14:00
#
#
# 0
#
# 0
#
# 木村次郎衆院議員が政治資金収支報告書を訂正へ　金額は「精査中」1/20 14:00
#
#
# 0
#
# 0
#
# 「法律が追いついていない」　武見厚労相、育児と仕事の両立支援へ1/20 13:30
#
#
# 0
#
# 0
#
# 意気投合した起業家とNPO、災害医療支援船に出資　互いに学び合い1/20 13:00
#
#
# 0
#
# 0
#
# 「洗練された街並み」「都心近い」　巨大マンション街に移る住民の声1/20 13:00
#
#
# 0
#
# 0
#
# 胸や腹に刺し傷、正面から襲われたか　夫婦遺体の床下遺棄事件　足立1/20 12:30
#
#
# 0
#
# 0
#
# 父から虐待、記念盾は「燃やせ」　中1の青葉被告は理不尽さに泣いた1/20 12:01
#
#
# 0
#
# 0
#
# 京アニそばの路地、座り込み10分考えた末に　青葉被告の半生を追う1/20 12:00
#
#
# 0
#
# 0
#
# 週末かなう運転士の夢、映画に出たあの電車で　都会にはないのんびり1/20 12:00
#
#
# 0
#
# 0
#
# 「VIVANT」で注目、空想地図作家　歴史も織り込むマニアな世界1/20 12:00
#
#
# 0
#
# 0
#
# 日独逆転、GDP4位に転落　「経済大国＝豊か」という幻想の先へ1/20 12:00
#
#
# 0
#
# 0
#
# 二階氏、自ら育てた「志帥会」にピリオド　「派閥悪いわけじゃない」1/20 12:00
#
#
# 0
#
# 0
#
# 能登半島地震、内陸の断層も動いたか　局所的に強い揺れで被害拡大？1/20 11:30
#
#
# 0
#
# 0
#
# 4年が雑用「当たり前じゃない」　帝京ラグビーが育む主体性と団結1/20 11:30
#
#
# 0
#
# 0
#
# 紗倉まなさんが考える多様性とは　拒絶するのではなく、受け止めて1/20 11:00
#
#
# 0
#
# 0
#
# 【マンガ動画】寒い時期の地震　避難時に準備したい防寒対策とは1/20 11:00
#
#
# 0
#
# 0
#
# 谷良一さん　たった一人から始まった「M-1グランプリ」1/20 11:00
#
#
# 0
#
# 0
#
# チョコ愛まみれで重く、厚く 阪急百貨店の無料冊子、もはや「鈍器」1/20 11:00
#
#
# 0
#
# 0
#
# プロ引退の決断におじいちゃんの言葉　「何かを得るときじゃけぇ」1/20 10:00
#
#
# 0
#
# 0
#
# 彼の年収は私の10倍…でもケチ　50代の相談に美輪明宏さんが回答1/20 10:00
#
#
# 0
#
# 0
#
# 「最年少」塗り替えたユウトとエイタ　プロバスケの舞台で高校生奮闘1/20 10:00
#
#
# 0
#
# 0
#
# パリで梅酒人気じわり　食習慣に狙い定め、ブランド化めざす生産県1/20 10:00
#
#
# 0
#
# 0
#
# レーニン埋葬に半数以上が賛成　没後100年でロシア世論調査1/20 10:00
#
#
# 0
#
# 0
#
# 市の電気代、2年間で7千万円削減　全国2例目の安上がりの仕組みは1/20 10:00
#
#
# 0
#
# 0
#
# チワワの子犬が海に転落、飼い主も冬の海へ…2つの命救う連携プレー1/20 09:30
#
#
# 0
#
# 0
#
# 来年度の年金、2.7%プラス改定　年金抑制措置が発動　実質目減り1/20 09:30
#
#
# 0
#
# 0
#
# 将来の年金給付水準を改善するには？　「総賃金」増やす工夫がカギ1/20 09:30
#
#
# 0
#
# 0
#
# 笑顔なき成功会見「ギリギリ合格60点」　月面着陸、いったい何が？1/20 09:30
#
#
# 0
#
# 0
#
# 震災10日後の死「避けられた」　父が訴えた異変、悔やむ医師はいま1/20 09:00
#
#
# 0
#
# 0
#
# 障害、難病、引きこもり…就労困難者ゼロへ　35歳起業家が走る1/20 09:00
#
#
# 0
#
# 0
#
# チューリップの球根には何があるの？　花を咲かす全部が詰まっている1/20 09:00
#
#
# 0
#
# 0
#
# オムツ売り場で光る「彼女たち」のスキル　起業ひらめいた社長の思い1/20 09:00
#
#
# 0
#
# 0
#
# MIXI創業者が共感　応援に乗り出した「子ども準シェルター」構想1/20 08:30
#
#
# 0
#
# 0
#
# マイナ保険証の利用率、8カ月連続低下　若年層ほど利用しない実態も1/20 08:30
#
#
# 0
#
# 0
#
# NYダウとS＆P500、ともに史上最高値　ハイテク株が値上がり1/20 08:25
#
#
# 0
#
# 0
#
# 空腹で思いついた可食ロボ、ひとりでに動くゲル…　注目のソフトロボ1/20 08:00
#
#
# 0
#
# 0
#
# 在阪4オケ、攻める来年度演目　生誕200年ブルックナー企画も1/20 08:00
#
#
# 0
#
# 0
#
# 17年前、赤ちゃんだった私はこの避難所にいた　再び被災して今度は1/20 08:00
#
#
# 0
#
# 0
#
# 立件された会計責任者3人　「政治の世界は素人」「気の毒」との声も1/20 08:00
#
#
# 0
#
# 0
#
# ゼレンスキー氏、トランプ氏をキーウへ招待の意向　英メディアで語る1/20 07:37
#
#
# 0
#
# 0
#
# 藤原崇衆院議員、14万円のキックバック認める　岩手3区選出1/20 07:31
#
#
# 0
#
# 0
#
# 約束を守れなかった少年のために　今も活動する74歳保護司の心残り1/20 07:30
#
#
# 0
#
# 0
#
# 石川に医療コンテナ18基、医療支援強化　1.5次避難所には診療所1/20 07:30
#
#
# 0
#
# 0
#
# パキスタンとイラン、緊張緩和で一致　攻撃の応酬で双方に死者1/20 07:30
#
#
# 0
#
# 0
#
# 押収された犬猫80匹が行方不明　動物愛護団体が神奈川県を提訴1/20 07:25
#
#
# 0
#
# 0
#
# 「ウクライナの医師」に150万円　70代女性が詐欺被害　福島1/20 07:22
#
#
# 0
#
# 0
#
# 東海第二原発が立地する東海村　村議選に立った新顔が訴えるのは1/20 07:00
#
#
# 0
#
# 0
#
# 「トランプ氏復権に備え、ウクライナ戦争止めよ」元外交官が停戦論1/20 07:00
#
#
# 0
#
# 0
#
# トランプ氏復活?ウクライナ停戦?　エコノミストが語る先読みの勘所1/20 07:00
#
#
# 0
#
# 0
#
# 「疑い晴れた」聴取終え、余裕の京成百貨店元社長　そのころ県警は1/20 07:00
#
#
# 0
#
# 0
#
# 球磨川豪雨で14人死亡の特養、高台で再建　「村の福祉の拠点に」1/20 07:00
#
#
# 0
#
# 0
#
# 「禁じ手」使ってでも被災者の悩み解消に奔走　地元金融マンの思い1/20 07:00
#
#
# 0
#
# 0
#
# 中学受験、千葉で本格化　渋幕は志願者増、市川微減　都内難関校は…1/20 07:00
#
#
# 0
#
# 0
#
# 「気性は荒いが誠実な面も」略式起訴の谷川弥一氏　支援者らの見方1/20 06:30
#
#
# 0
#
# 0
#
# 五輪レガシーで交流人口増の夢　国内外から選手集う「空手のまち」へ1/20 06:00
#
#
# 0
#
# 0
#
# フィリピン国籍の女、2遺体を床下収納の下に遺棄か　トラブル相談も1/20 06:00
#
#
# 0
#
# 0
#
# 生活感覚とかけ離れた政治の世界　裏金「裏切り行為でしかない」1/20 06:00
#
#
# 0
#
# 0
#
# 改めるべきは、政治とカネ繰り返す体質だ　首相の「岸田派解散」宣言1/20 06:00
#
#
# 0
#
# 0
#
# 温室効果ガス削減40%目標、GXリーグ企業公表　政府目標に届かず1/20 05:00
#
#
# 0
#
# 0
#
# 「私は派閥やめませんから」　首相に告げた麻生氏、三派連合の終焉1/20 05:00
#
#
# 0
#
# 0
#
# 「山場は検審　緊張して待つ」　政治資金問題は「民意」の判断へ1/20 05:00
#
#
# 0
#
# 0
#
# 探査機SLIMが月面に軟着陸　JAXA発表、太陽電池は発電せず1/20 02:36
#
#
# 0
#
# 0
#
# 「ロシア、10年内にNATO攻撃」　独国防相が予測、強まる警戒感1/20 01:00
#
#
# 0
#
# 0
#
# プーチン氏、1年2カ月ぶりに駐日大使を任命　日本語と英語が堪能1/20 00:15
#
#
# 0
#
# 0
#
# 日本、まさかの黒星　「15分」与えてくれなかったイラク　アジア杯1/19 23:32
#
#
# 0
#
# 0
#
# 東京地検次席検事「私が説明する必要がある」　派閥裏金事件で会見1/19 22:53
#
#
# 0
#
# 0
#
# 【詳報】日本、1-2でイラクに敗れ1勝1敗　遠藤が得点　アジア杯1/19 22:38
#
#
# 0
#
# 0
#
# 【詳報】橋本聖子氏、受け取った裏金は2057万円　議員辞職否定1/19 22:16
#
#
# 0
#
# 0
#
# 「格下相手に…」自嘲した照ノ富士、復帰場所で確認したいこと1/19 22:10
#
#
# 0
#
# 0
#
# 「パパさんプレーヤー」って言う？　スポーツ中継で求められる多様性1/19 22:00
#
#
# 0
#
# 0
#
# 医療や介護など「報酬改定に見合う賃上げ実現を」　首相、団体に要請1/19 21:55
#
#
# 0
#
# 0
#
# 「国王にも所得税を」オランダ議会、動議を可決へ　収入半減に？1/19 21:46
#
#
# 0
#
# 0
#
# 中国側、ビザ免除で「相応の行動」 求める 社民党福島氏との会談で1/19 21:30
#
#
# 0
#
# 0
#
# 祖父は自民結党の重鎮、政治一家の大野議員「裏金」に揺れる保守王国1/19 21:30
#
#
# 0
#
# 0
#
# 安倍、二階、岸田派の会計責任者を在宅起訴　安倍派幹部は立件せず1/19 21:21
#
#
# 0
#
# 0
#
# 野党「派閥離脱はフェイク」　無派閥の首相による岸田派解散宣言に1/19 21:18
#
#
# 0
#
# 0
#
# 朝鮮人追悼碑、近く撤去へ　県立公園「群馬の森」　県が代執行方針1/19 21:00
#
#
# 0
#
# 0
#
# 「忘年会でラリアット、休日勤務命令」　パワハラで病院長を戒告処分1/19 21:00
#
#
# 0
#
# 0
#
# このまま衆院選なら愛知は「全滅も」…問題続出で自民関係者に危機感1/19 21:00
#
#
# 0
#
# 0
#
# 札幌国際芸術祭、6年半ぶりに開幕　テーマは「LAST　SNOW」1/19 21:00
#
#
# 0
#
# 0
#
# 国会前でデモ　「裏金議員やめさせたい」「選んだのは私たち」1/19 20:59
#
#
# 0
#
# 0
#
# 岡山県警交通部長が昇任試験問題漏洩か　国家公務員法違反容疑で捜査1/19 20:50
#
#
# 0
#
# 0
#
# 安倍派5人衆ら立件見送り、検察は批判も意識　幹部「冷静な判断だ」1/19 20:35
#
#
# 0
#
# 0
#
# 大学病院勤務医、教育・研究の「研鑽」は労働に該当　厚労省が明示1/19 20:30
#
#
# 0
#
# 0
#
# 食べログが逆転勝訴　アルゴリズム変更「合理的」、独禁法違反認めず1/19 20:21
#
#
# 0
#
# 0
#
# イスラエル首相、「2国家解決」を否定　戦闘支える米国と溝深まる1/19 20:18
#
#
# 0
#
# 0
#
# 4年ぶり神戸ルミナリエ開幕　一部有料化や時期変更など「実験」の年1/19 20:06
#
#
# 0
#
# 0
#
# 「復興まで見捨てられない」　輪島朝市で夜通し消火活動した消防団員1/19 20:00
#
#
# 0
#
# 0
#
# 在宅起訴された大野議員、虚偽記載への関与を認めず　辞職も否定1/19 20:00
#
#
# 0
#
# 0
#
# 「東京BRT」に選手村ルート　晴海フラッグと新橋を11分で1/19 19:59
#
#
# 0
#
# 0
#
# 大手電力業界のトップ、後任選び始まる　現会長「全員資質あり」1/19 19:53
#
#
# 0
#
# 0
#
# ダイハツ、2月に一部生産再開も　国交省が5車種の出荷停止解除1/19 19:45
#
#
# 0
#
# 0
#
# 自民の最大派閥、安倍派も解散方針を決める　岸田派、二階派に続き1/19 19:34
#
#
# 0
#
# 0
#
# 輪島朝市の現場「あの時と同じ」　阪神大震災で救助活動の消防隊員1/19 19:30
#
#
# 0
#
# 0
#
# 日本航空高校石川の野球部が山梨で練習を再開　能登半島地震で被災1/19 19:30
#
#
# 0
#
# 0
#
# 市長パワハラ　アンケ回答の職員6割が「見聞き」、2割は「受けた」1/19 19:30
#
#
# 0
#
# 0
#
# 北海道新幹線、青函トンネル内初の260キロ走行　大型連休の5日間1/19 19:30
#
#
# 0
#
# 0
#
# 朝日新聞デジタルトップに戻る
# 朝日新聞デジタルトップに戻る
